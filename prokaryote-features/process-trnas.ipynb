# %%
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (15, 6)
mpl.style.use('ggplot')
import pandas as pd
import numpy
import subprocess
import glob
import re
import os, sys
from collections import defaultdict, Counter, OrderedDict
from Bio import SeqIO, SeqRecord, Seq
from tRNA_position import *
pd.set_option('display.max_colwidth',10000)
pd.set_option('display.width', 10000)
pd.set_option('display.max_columns', 10000)
pd.set_option('display.max_rows',1000)
isotypes = ['Ala', 'Arg', 'Asn', 'Asp', 'Cys', 'Gln', 'Glu', 'Gly', 'His', 'Ile', 'Ile2', 'iMet', 'fMet', 'Leu', 'Lys', 'Met', 'Phe', 'Pro', 'Ser', 'Thr', 'Trp', 'Tyr', 'Val']

# %% [markdown]
# # Introduction
#
# A global view of identity elements versus biological features would be a powerful tool for predicting tRNA function using primary sequence. I've done this for eukaryotic tRNAs, so this is an extension to prokaryotes.

# %% [markdown]
# # Process tRNAs
# ## Species information

# %%
species_table = pd.read_table('genomes-101217.tsv', header=None, names=['species', 'longname', 'domain', 'clade', 'taxid'], dtype={'taxid': str})
species_table.head()
# Out:
#      species                             longname   domain          clade         taxid
# 0  acidHosp1              Acidianus hospitalis W1  archaea  Crenarchaeota  Thermoprotei
# 1  acidSacc1     Acidilobus saccharovorans 345-15  archaea  Crenarchaeota  Thermoprotei
# 2    aerPer1                  Aeropyrum pernix K1  archaea  Crenarchaeota  Thermoprotei
# 3  caldMaqu1     Caldivirga maquilingensis IC-167  archaea  Crenarchaeota  Thermoprotei
# 4  desuKamc1  Desulfurococcus kamchatkensis 1221n  archaea  Crenarchaeota  Thermoprotei

# %% [markdown]
# The following species are removed because of a lack of `.iso` file:
# - nitrMari1
# - pyroIsla1
# - therNeut1
#
# Also, nanEqu1 is removed because the most recent run doesn't contain tRNA$^\textrm{Glu}$.

# %%
species = sorted(glob.glob("out/*-tRNAs.out"))
species = [sp[4:-10] for sp in species]
seqs = []

for sp in species:

  tRNA_file = 'tRNAs/{}-tRNAs.fa'.format(sp)
  tscanout_file = 'out/{}-tRNAs.out'.format(sp)
  ss_file = 'ss/{}-tRNAs.ss'.format(sp)
  iso_file = 'iso/{}-tRNAs.iso'.format(sp)

  # Import annotation from tRNAscan .out files. We want to keep everything that's not "Pseudo"
  approved_tRNAs = []
  intron_lengths = [] # we are purging introns to improve alignment, so store intron lengths here
  for metadata in pd.read_table(tscanout_file, sep="\t", skiprows=3, header=None).iterrows():
    if metadata[1].iloc[-1] in ["Pseudo", "Isotype mismatch;Pseudo"]: continue
    if metadata[1][4] == "Undet": continue
    approved_tRNAs.append('{}.trna{}-{}{}'.format(metadata[1][0].strip(), metadata[1][1], metadata[1][4], metadata[1][5]))
    if type(metadata[1][6]) == str:
      intron_length = ','.join([str(abs(int(start) - int(end)) + 1) for start, end in zip(metadata[1][6].split(','), metadata[1][7].split(','))])
    else:
      intron_length = abs(int(metadata[1][6]) - int(metadata[1][7]))
      if intron_length > 0: intron_length = intron_length + 1
    intron_lengths.append(intron_length)
      
  # Remove introns using sstofa
  subprocess.call('sstofa3 {} "" 1 0 > {}'.format(ss_file, tRNA_file), shell=True)

  # Parse isotype-specific scores file
  iso_scores = pd.read_table(iso_file, header=0)
  iso_scores['Undet'] = 0
  iso_scores['Sup'] = 0
  if 'iMet' not in iso_scores: iso_scores['iMet'] = 0
  if 'fMet' not in iso_scores: iso_scores['fMet'] = 0
  if 'Ile2' not in iso_scores: iso_scores['Ile2'] = 0
  iso_scores['best'] = iso_scores.iloc[:,2:].idxmax(axis=1)
  iso_scores['score'] = iso_scores.max(axis=1, numeric_only=True)
  iso_scores['ac_score'] = iso_scores.lookup(iso_scores.index, iso_scores.iloc[:, 1])
  iso_scores.index = iso_scores.tRNAscanID.values
  iso_scores = iso_scores[['best', 'score', 'ac_score']]
  
  # Compile sequence information into a list
  for seq in SeqIO.parse('tRNAs/{}-tRNAs.fa'.format(sp), 'fasta'):
    if seq.id not in approved_tRNAs: continue
    if "pseudogene" in seq.description: continue
    
    # filter low-scoring tRNAs
    score = float(re.findall('Sc: [\d\.]+', seq.description)[0].split()[-1])
    if score < 50: continue
    
    # get tRNA attributes
    intron_length = intron_lengths[approved_tRNAs.index(seq.id)]
    trnascanid = re.findall('.+\.trna\d+', seq.id)[0]
    isotype = iso_scores.loc[trnascanid].best
    
    # filter selenocysteine tRNAs - these have a different 2d structure
    if isotype == 'SeC': continue
    isoscore, ac_score = iso_scores.loc[trnascanid].score, iso_scores.loc[trnascanid].ac_score
    seq.id = '{}|{} Iso: {} ({}) Iso_ac: {} Intron: {}'.format(sp, seq.description, isoscore, isotype, ac_score, intron_length)
    seq.description = ''
    seqs.append(seq)

# %%
fasta_handle = open('pro-tRNAs.fa', 'w')
SeqIO.write(seqs, fasta_handle, 'fasta')
fasta_handle.close()
num_model = '/projects/lowelab/users/blin/tRNAscan/models/domain-specific/pro-num-091217.cm'
subprocess.call('cmalign -g --notrunc -o pro-tRNAs.sto {} pro-tRNAs.fa'.format(num_model), shell=True)
# Out:
# 0

# %% [markdown]
# ## Create table of tRNA bases by position
#
# This is a giant data frame with one row per tRNA, and with columns for each position, plus tRNA metadata like species and loop lengths.

# %%
def position_base(positions, seq):
  for position_index, position in enumerate(positions):
    if position.paired:
      index1, index2 = position.position.split(':')
      index1, index2 = int(index1), int(index2)
      base_pair = "{}:{}".format(seq[index1 - 1].upper(), seq[index2 - 1].upper())
      yield position.sprinzl, base_pair
    else:
      index = int(position.position)
      base = seq[index - 1].upper()
      yield position.sprinzl, base
      
identities = pd.DataFrame()

# get positions
alignment_fhandle = open('pro-tRNAs.sto')
positions = [] # list containing each position in the tRNA

# first, get secondary structure
# also count the number of lines for progress bar
ss_count = 0
for line in alignment_fhandle:
  if line[0:4] == "#=GR": ss_count += 1
  if line[0:12] == '#=GC SS_cons':
    ss = line.strip().split()[-1]
alignment_fhandle.close()

# parse secondary structure into regions and positions
positions = annotate_positions(ss)

# get nucleotide at each position for each tRNA by parsing Stockholm file
alignment_fhandle = open('pro-tRNAs.sto')
trnas = []
skipped = []
n = 0
for line in alignment_fhandle:
  if line[0] in ["#", '\n', '/']: continue
  
  # status update
  n += 1
  if n % int(ss_count / 10) == 0: print("{} tRNAs processed ({}%)".format(n, round(n / ss_count * 100)))
  sys.stdout.flush()
  
  # parse secondary structure
  species, desc = line.strip().split('|', 1)
  seqname = desc.split()[0]
  seq = desc.split()[-1]
  if any(species_table.species == species):
    row = species_table[species_table.species == species]
  else: 
    skipped.append(species)
    continue
  isotype = re.findall('\.trna\d+-([A-Za-z]+)', seqname)[0][:-3]
  seqname = '{}_{}'.format(species, seqname)
  trna = {'domain': row.domain.values[0], 'clade': row.clade.values[0], 'species': species, 'species_long': row.longname.values[0], 'taxid': row.taxid.values[0], 'seqname': seqname, 'isotype': isotype}
  trna = {**trna, **{sprinzl: base for sprinzl, base in position_base(positions, seq)}}
  trnas.append(trna)

if len(skipped) > 0: print('skipped the following: {}'.format(set(skipped)))
identities = identities.append(trnas, ignore_index=True)
identities.fillna('.', inplace=True)
alignment_fhandle.close()
# Out:
# 18957 tRNAs processed (10%)
# 37914 tRNAs processed (20%)
# 56871 tRNAs processed (30%)
# 75828 tRNAs processed (40%)
# 94785 tRNAs processed (50%)
# 113742 tRNAs processed (60%)
# 132699 tRNAs processed (70%)
# 151656 tRNAs processed (80%)
# 170613 tRNAs processed (90%)
# 189570 tRNAs processed (100%)
# skipped the following: {'metaSedu_CUR1', 'candNitr_EVERGLADENSIS_SR1', 'desuFerm_DSM16532', 'vibrVuln_CMCP6', 'natrTher_JW_NM_WN_LF', 'leptBorg_HARDJO_BOVIS_L550', 'sulfIsla_M_16_43', 'methBark_WIESMOOR', 'persMari_EX_H1', 'candNitr_SP_AR2', 'rhodMari_DSM4252', 'gloeViol_PCC_7421', 'candNitr_GARGENSIS_GA9_2', 'therElon_BP_1', 'candDesu_AUDAXVIATOR_MP104C', 'actiPleu_5B_L20', 'lactDelb_BULGARICUS_ATCC_1', 'methConr1', 'sulfAzor_AZ_FU1', 'sulfSolf_98_2_SULC', 'rhodMari_SG0_5JP17_172', 'nitrVien_EN76', 'nostSp_PCC_7120', 'therCarb_1505', 'eschColi_B_REL606', 'streTher_LMG_18311', 'bifiLong_NCC2705', 'nocaFarc_IFM_10152', 'saliRube_DSM13855_M31', 'leptInte_LAI_56601', 'haloWals_DSM16790_HBSQ001', 'hydrTher_TK_6', 'vibrVuln_YJ016', 'shewBalt_OS155', 'sulfAcid_SUSAZ', 'caldLagu_DSM15908', 'haloHisp_ATCC33960_CGMCC_1_204', 'shewDeni_OS217', 'oceaIhey_HTE831', 'sulfAcid_N8', 'butyProt_B316', 'shewSp_ANA_3', 'koraCryp1', 'flavPsyc_JIP02_86', 'haemInfl_RD_KW20', 'shewSp_MR_4', 'pectAtro_SCRI1043', 'buchAphi_APS_ACYRTHOSIPHON', 'haloSali_R1_DSM671', 'wiggGlos_ENDOSYMBIONT_OF_GLOSS', 'caldSubt1', 'shewAmaz_SB2B', 'methBoon_6A8', 'shewLoih_PV_4', 'ammoDege_KC4', 'shewOnei_MR_1', 'nanEqu1', 'lactPlan_WCFS1', 'candNitr_KOREENSIS_AR1', 'carbHydr_Z_2901', 'sulfIsla_M_16_40', 'shigFlex_2A_301', 'streTher_CNRZ1066', 'thauArch_SAT1', 'therCurv_DSM43183', 'sulfAcid_RON12_I', 'sulfSolf_SULB', 'aquiAeol_VF5', 'streTher_LMD_9', 'franTula_HOLARCTICA_OSU1', 'candMeth_INTESTINALIS_ISSOIRE', 'sulfIsla_HVE10_4', 'borrBurg_B31', 'haloMedi_ATCC33500_CGMCC_1_208', 'leptBorg_HARDJO_BOVIS_JB197', 'vibrChol_O395', 'aeroCami_SY1_JCM_12091', 'baciHalo_C_125', 'anoxFlav_WK1', 'candNitr_SP_D3C', 'candMeth_ALVUS_MX1201', 'pyrAby1', 'saliRube_M8', 'shewSp_MR_7', 'therSp_1910B', 'sulfIsla_M_16_47', 'haloBori_DSM11551_PR_3', 'shewPeal_ATCC700345', 'shewHali_HAW_EB4', 'sulfIsla_LAL14_1', 'shewPutr_CN_32', 'exigSp_AT1B', 'fervFont_KAM940', 'eschColi_O157_H7_EDL933', 'yersPseu_IP_31758', 'shewFrig_NCIMB_400', 'closPerf_SM101', 'syneSp_PCC_6803', 'ferrAcid2', 'acidFerr_DSM10331', 'coxiBurn_RSA_493', 'methSmit_ATCC35061_PS_DSMZ_861', 'pseuAeru_PAO1', 'therGamm_EJ3_DSM15229', 'pyroFuma1', 'sulfIsla_M_16_23', 'yersPseu_IP_32953', 'natrPhar_DSM2160_GABARA', 'shewSp_W3_18_1', 'shewWood_ATCC51908', 'candNitr_SP_NF5', 'therCell_1633', 'strePneu_R6', 'sulfSolf_SULA', 'vibrChol_O1_EL_TOR_N16961', 'xyleFast_9A5C', 'sulfIsla_M_16_2'}

# %% [markdown]
# ### Create single base columns from paired positions

# %%
cols = list(filter(lambda x: ':' in x, identities.columns))
for col in cols:
  pos1, pos2 = col.split(':')
  base1 = [bases.split(':')[0] for bases in identities[col]]
  base2 = [bases.split(':')[1] for bases in identities[col]]
  identities[pos1] = base1
  identities[pos2] = base2

# %% [markdown]
# ### Additional sequence information

# %%
# Isotype, anticodon, score, isoscores
seqinfo = []
for line in open('pro-tRNAs.sto'):
  if line[0:4] != "#=GS": continue
  _, desc, _, _, isotype, anticodon, _, _, _, score, _, isoscore, isotype_best, _, isoscore_ac, _, intron_length = line.strip().split()
  seqname = desc.replace('|', '_', 1)
  seqinfo.append([seqname, isotype_best[1:-1], anticodon[1:-1], float(score), float(isoscore), float(isoscore_ac), str(intron_length)])
seqinfo = pd.DataFrame(seqinfo, columns=['seqname', 'isotype_best', 'anticodon', 'score', 'isoscore', 'isoscore_ac', 'intron'])
identities = identities.merge(seqinfo, on='seqname')

# iMet/fMet/Ile2 is likely not to be properly annotated
identities.loc[identities.loc[identities.isotype_best == "iMet", ].index, 'isotype'] = 'iMet'
identities.loc[identities.loc[identities.isotype_best == "fMet", ].index, 'isotype'] = 'fMet'
identities.loc[identities.loc[identities.isotype_best == "Ile2", ].index, 'isotype'] = 'Ile2'

# GC content
paired_cols = identities.columns[list(map(lambda x: (':' in x), identities.columns))]
identities['GC'] = identities[paired_cols].apply(lambda x: sum((x == "G:C") | (x == "C:G"))/len(paired_cols), axis=1)

# %% [markdown]
# ### Insertions/deletions
#
# This doesn't take into account noncanonical introns in archaea.

# %%
# Insertions (minus misaligned introns at 37/38)
intron_cols = list(filter(lambda x: x[0:3] == '37i', identities.columns))
insertion_cols = list(filter(lambda x: bool(re.search('^\d+i', x)) & (x not in intron_cols), identities.columns))
identities['insertions'] = identities[insertion_cols].apply(lambda x: sum(x != '.'), axis=1)

# Deletions at positions that are not the variable arm, and not counting 17/17a/20a/20b
base_cols = list(filter(lambda x: bool(re.match('^\d+$', x)) & (x not in ['74', '75', '76', '17', '17a', '20a', '20b']), identities.columns))
identities['deletions'] = identities[base_cols].apply(lambda x: ''.join(x).count('-'), axis=1)

# %% [markdown]
# ### Restrict tRNAs by species
#
# We may also want to limit the contribution of any single species, similar to how we built the isotype-specific models. The restricted set is a subset of the quality set.

# %%
identities.shortname = identities.species
identities.species = numpy.apply_along_axis(numpy.vectorize(lambda x: ' '.join(x.split(' ')[:2])), 0, identities.species_long)

# %%
identities.loc[:, 'restrict'] = False
for species in identities.species.unique():
  sys.stdout.write("Processing {}...".format(species))
  sys.stdout.flush()
  species_df = identities.loc[identities.species == species, :]

  for isotype in isotypes:
    sys.stdout.flush()
    isotype_indices = identities.loc[(identities.species == species) & (identities.isotype == isotype) & (-identities.restrict), ].index
    unique_scores_indices = isotype_indices[-identities.loc[isotype_indices, 'score'].duplicated()]
    unique_scores_indices = unique_scores_indices[numpy.argsort(identities.loc[unique_scores_indices, 'score'])][::-1][:50]
    restricted_indices = list(set(isotype_indices) - set(unique_scores_indices))    
    identities.loc[restricted_indices, 'restrict'] = True

  print("done")
  sys.stdout.flush()
# Out:
# Processing Acaryochloris marina...done
# Processing Acetohalobium arabaticum...done
# Processing Acetobacterium woodii...done
# Processing Aciduliprofundum boonei...done
# Processing Acidithiobacillus caldus...done
# Processing Acidothermus cellulolyticus...done
# Processing Acidaminococcus fermentans...done
# Processing Acidithiobacillus ferrooxidans...done
# Processing Acidithiobacillus ferrivorans...done
# Processing Acidianus hospitalis...done
# Processing Acidaminococcus intestini...done
# Processing Acidilobus saccharovorans...done
# Processing Aciduliprofundum sp....done
# Processing Acinetobacter baumannii...done
# Processing Acinetobacter calcoaceticus...done
# Processing Acinetobacter oleivorans...done
# Processing Acinetobacter sp....done
# Processing Actinobacillus equuli...done
# Processing Actinoplanes friuliensis...done
# Processing Actinosynnema mirum...done
# Processing Actinoplanes missouriensis...done
# Processing Actinobacillus pleuropneumoniae...done
# Processing Actinobaculum schaalii...done
# Processing Actinoplanes sp....done
# Processing Actinobacillus succinogenes...done
# Processing Actinobacillus suis...done
# Processing Adlercreutzia equolifaciens...done
# Processing Aequorivita sublithincola...done
# Processing Aeropyrum pernix...done
# Processing Aeromonas hydrophila...done
# Processing Aeromonas media...done
# Processing Aeromonas salmonicida...done
# Processing Aerococcus urinae...done
# Processing Aeromonas veronii...done
# Processing Aggregatibacter actinomycetemcomitans...done
# Processing Aggregatibacter aphrophilus...done
# Processing Alcanivorax borkumensis...done
# Processing Alcanivorax dieselolei...done
# Processing Alcanivorax pacificus...done
# Processing Algoriphagus machipongonensis...done
# Processing Alicyclobacillus acidocaldarius...done
# Processing Aliivibrio salmonicida...done
# Processing Aliivibrio wodanis...done
# Processing Alistipes finegoldii...done
# Processing Alistipes shahii...done
# Processing Alkalilimnicola ehrlichii...done
# Processing Alkaliphilus metalliredigens...done
# Processing Alkaliphilus oremlandii...done
# Processing Allochromatium vinosum...done
# Processing Alteromonas australica...done
# Processing Alteromonas macleodii...done
# Processing Alteromonas sp....done
# Processing Amphibacillus xylanus...done
# Processing Amycolatopsis japonica...done
# Processing Amycolatopsis lurida...done
# Processing Amycolatopsis mediterranei...done
# Processing Amycolatopsis methanolica...done
# Processing Amycolatopsis orientalis...done
# Processing Amycolicicoccus subflavus...done
# Processing Anabaena cylindrica...done
# Processing Anabaena sp....done
# Processing Anabaena variabilis...done
# Processing Anaerococcus prevotii...done
# Processing Arcanobacterium haemolyticum...done
# Processing Archaeoglobus fulgidus...done
# Processing Archaeoglobus profundus...done
# Processing Archaeoglobus sulfaticallidus...done
# Processing Archaeoglobus veneficus...done
# Processing Arthrobacter arilaitensis...done
# Processing Arthrobacter aurescens...done
# Processing Arthrobacter chlorophenolicus...done
# Processing Arthrobacter phenanthrenivorans...done
# Processing Arthrospira platensis...done
# Processing Arthrobacter sp....done
# Processing Arthrospira sp....done
# Processing Atopobium parvulum...done
# Processing Azotobacter chroococcum...done
# Processing Azotobacter vinelandii...done
# Processing Bacillus amyloliquefaciens...done
# Processing Bacillus anthracis...done
# Processing Bacillus atrophaeus...done
# Processing Bacillus bombysepticus...done
# Processing Bacillus cellulosilyticus...done
# Processing Bacillus cereus...done
# Processing Bacillus clausii...done
# Processing Bacillus coagulans...done
# Processing Bacillus cytotoxicus...done
# Processing Bacillus infantis...done
# Processing Bacillus lehensis...done
# Processing Bacillus licheniformis...done
# Processing Bacillus megaterium...done
# Processing Bacillus methylotrophicus...done
# Processing Bacillus methanolicus...done
# Processing Bacillus mycoides...done
# Processing Bacillus pseudofirmus...done
# Processing Bacillus pumilus...done
# Processing Bacillus selenitireducens...done
# Processing Bacillus sp....done
# Processing Bacillus subtilis...done
# Processing Bacillus thuringiensis...done
# Processing Bacillus toyonensis...done
# Processing Bacillus weihenstephanensis...done
# Processing Bacteroidales bacterium...done
# Processing Bacteroides dorei...done
# Processing Bacteroides fragilis...done
# Processing Bacteroides helcogenes...done
# Processing Bacteroides salanitronis...done
# Processing Bacteroides thetaiotaomicron...done
# Processing Bacteroides vulgatus...done
# Processing Bacteroides xylanisolvens...done
# Processing Barnesiella viscericola...done
# Processing Belliella baltica...done
# Processing Beutenbergia cavernae...done
# Processing Bibersteinia trehalosi...done
# Processing Bifidobacterium adolescentis...done
# Processing Bifidobacterium animalis...done
# Processing Bifidobacterium asteroides...done
# Processing Bifidobacterium bifidum...done
# Processing Bifidobacterium breve...done
# Processing Bifidobacterium coryneforme...done
# Processing Bifidobacterium dentium...done
# Processing Bifidobacterium indicum...done
# Processing Bifidobacterium kashiwanohense...done
# Processing Bifidobacterium longum...done
# Processing Bifidobacterium pseudolongum...done
# Processing Bifidobacterium thermophilum...done
# Processing Blastococcus saxobsidens...done
# Processing Blattabacterium sp....done
# Processing Blochmannia endosymbiont...done
# Processing Borrelia afzelii...done
# Processing Borrelia bissettii...done
# Processing Borrelia burgdorferi...done
# Processing Borrelia chilensis...done
# Processing Borrelia crocidurae...done
# Processing Borrelia duttonii...done
# Processing Borrelia garinii...done
# Processing Borrelia hermsii...done
# Processing Borrelia miyamotoi...done
# Processing Borrelia parkeri...done
# Processing Borrelia recurrentis...done
# Processing Borrelia turicatae...done
# Processing Borrelia valaisiana...done
# Processing Brachybacterium faecium...done
# Processing Brachyspira hyodysenteriae...done
# Processing Brachyspira intermedia...done
# Processing Brachyspira murdochii...done
# Processing Brachyspira pilosicoli...done
# Processing Brevibacillus brevis...done
# Processing Brevibacillus laterosporus...done
# Processing Buchnera aphidicola...done
# Processing butyrate-producing bacterium...done
# Processing Butyrivibrio fibrisolvens...done
# Processing Caldicellulosiruptor bescii...done
# Processing Caldicellulosiruptor hydrothermalis...done
# Processing Caldicellulosiruptor kristjanssonii...done
# Processing Caldicellulosiruptor kronotskyensis...done
# Processing Caldicellulosiruptor lactoaceticus...done
# Processing Caldivirga maquilingensis...done
# Processing Caldicellulosiruptor obsidiansis...done
# Processing Caldicellulosiruptor owensensis...done
# Processing Caldicellulosiruptor saccharolyticus...done
# Processing Caldanaerobacter subterraneus...done
# Processing Calothrix sp....done
# Processing Candidatus Amoebophilus...done
# Processing Candidatus Arthromitus...done
# Processing Candidatus Atelocyanobacterium...done
# Processing Candidatus Azobacteroides...done
# Processing Candidatus Baumannia...done
# Processing Candidatus Blochmannia...done
# Processing Candidatus Carsonella...done
# Processing Candidatus Evansia...done
# Processing Candidatus Hamiltonella...done
# Processing Candidatus Ishikawaella...done
# Processing Candidatus Methanoplasma...done
# Processing Candidatus Moranella...done
# Processing Candidatus Pantoea...done
# Processing Candidatus Portiera...done
# Processing Candidatus Riesia...done
# Processing Candidatus Ruthia...done
# Processing Candidatus Sodalis...done
# Processing Candidatus Sulcia...done
# Processing Candidatus Uzinura...done
# Processing Capnocytophaga canimorsus...done
# Processing Capnocytophaga ochracea...done
# Processing Cardinium endosymbiont...done
# Processing Carnobacterium maltaromaticum...done
# Processing Carnobacterium sp....done
# Processing Catenulispora acidiphila...done
# Processing Cedecea neteri...done
# Processing Cellulophaga algicola...done
# Processing Cellulophaga baltica...done
# Processing Cellulomonas fimi...done
# Processing Cellulomonas flavigena...done
# Processing Cellvibrio gilvus...done
# Processing Cellvibrio japonicus...done
# Processing Cellulophaga lytica...done
# Processing Chamaesiphon minutus...done
# Processing Chitinophaga pinensis...done
# Processing Chromohalobacter salexigens...done
# Processing Chroococcidiopsis thermalis...done
# Processing Chryseobacterium sp....done
# Processing Citrobacter freundii...done
# Processing Citrobacter koseri...done
# Processing Citrobacter rodentium...done
# Processing Clavibacter michiganensis...done
# Processing Clostridium acetobutylicum...done
# Processing Clostridium autoethanogenum...done
# Processing Clostridium baratii...done
# Processing Clostridium beijerinckii...done
# Processing Clostridium botulinum...done
# Processing Clostridium cellulosi...done
# Processing Clostridium cellulovorans...done
# Processing Clostridium cellulolyticum...done
# Processing Clostridium cf....done
# Processing Clostridium clariflavum...done
# Processing Clostridium kluyveri...done
# Processing Clostridium ljungdahlii...done
# Processing Clostridium novyi...done
# Processing Clostridium pasteurianum...done
# Processing Clostridium perfringens...done
# Processing Clostridium saccharobutylicum...done
# Processing Clostridium saccharoperbutylacetonicum...done
# Processing Clostridium saccharolyticum...done
# Processing Clostridium scatologenes...done
# Processing Clostridium sordellii...done
# Processing Clostridium sp....done
# Processing Clostridium sporogenes...done
# Processing Clostridium stercorarium...done
# Processing Clostridium sticklandii...done
# Processing Clostridium tetani...done
# Processing Colwellia psychrerythraea...done
# Processing Conexibacter woesei...done
# Processing Coprococcus catus...done
# Processing Coprothermobacter proteolyticus...done
# Processing Coprococcus sp....done
# Processing Coriobacteriaceae bacterium...done
# Processing Coriobacterium glomerans...done
# Processing Corynebacterium argentoratense...done
# Processing Corynebacterium atypicum...done
# Processing Corynebacterium aurimucosum...done
# Processing Corynebacterium callunae...done
# Processing Corynebacterium camporealensis...done
# Processing Corynebacterium casei...done
# Processing Corynebacterium diphtheriae...done
# Processing Corynebacterium doosanense...done
# Processing Corynebacterium efficiens...done
# Processing Corynebacterium falsenii...done
# Processing Corynebacterium glutamicum...done
# Processing Corynebacterium glyciniphilum...done
# Processing Corynebacterium halotolerans...done
# Processing Corynebacterium humireducens...done
# Processing Corynebacterium imitans...done
# Processing Corynebacterium jeikeium...done
# Processing Corynebacterium kroppenstedtii...done
# Processing Corynebacterium kutscheri...done
# Processing Corynebacterium marinum...done
# Processing Corynebacterium maris...done
# Processing Corynebacterium pseudotuberculosis...done
# Processing Corynebacterium resistens...done
# Processing Corynebacterium singulare...done
# Processing Corynebacterium sp....done
# Processing Corynebacterium terpenotabidum...done
# Processing Corynebacterium ulcerans...done
# Processing Corynebacterium urealyticum...done
# Processing Corynebacterium ureicelerivorans...done
# Processing Corynebacterium variabile...done
# Processing Corynebacterium vitaeruminis...done
# Processing Coxiella burnetii...done
# Processing Coxiella endosymbiont...done
# Processing Crinalium epipsammum...done
# Processing Croceibacter atlanticus...done
# Processing Cronobacter sakazakii...done
# Processing Cronobacter turicensis...done
# Processing Cryptobacterium curtum...done
# Processing Cyanobacterium aponinum...done
# Processing cyanobacterium endosymbiont...done
# Processing Cyanobium gracile...done
# Processing Cyanothece sp....done
# Processing Cyanobacterium stanieri...done
# Processing Cyclobacterium marinum...done
# Processing Cycloclasticus sp....done
# Processing Cycloclasticus zancles...done
# Processing Cylindrospermum stagnale...done
# Processing Cytophaga hutchinsonii...done
# Processing Dactylococcopsis salina...done
# Processing Dehalobacter restrictus...done
# Processing Dehalobacter sp....done
# Processing Dermacoccus nishinomiyaensis...done
# Processing Desulfotomaculum acetoxidans...done
# Processing Desulfosporosinus acidiphilus...done
# Processing Desulfotomaculum carboxydivorans...done
# Processing Desulfitobacterium dehalogenans...done
# Processing Desulfitobacterium dichloroeliminans...done
# Processing Desulfotomaculum gibsoniae...done
# Processing Desulfitobacterium hafniense...done
# Processing Desulfurococcus kamchatkensis...done
# Processing Desulfotomaculum kuznetsovii...done
# Processing Desulfosporosinus meridiei...done
# Processing Desulfitobacterium metallireducens...done
# Processing Desulfurococcus mucosus...done
# Processing Desulfosporosinus orientis...done
# Processing Desulfotomaculum reducens...done
# Processing Desulfotomaculum ruminis...done
# Processing Dichelobacter nodosus...done
# Processing Dickeya dadantii...done
# Processing Dickeya zeae...done
# Processing Dokdonia sp....done
# Processing Draconibacterium orientale...done
# Processing Dyadobacter fermentans...done
# Processing Dyella japonica...done
# Processing Dyella jiangningensis...done
# Processing Echinicola vietnamensis...done
# Processing Edwardsiella ictaluri...done
# Processing Edwardsiella piscicida...done
# Processing Edwardsiella tarda...done
# Processing Eggerthella lenta...done
# Processing Eggerthella sp....done
# Processing Elizabethkingia anophelis...done
# Processing Elizabethkingia sp....done
# Processing Emticicia oligotrophica...done
# Processing endosymbiont of...done
# Processing Enterobacter aerogenes...done
# Processing Enterobacter asburiae...done
# Processing Enterobacteriaceae bacterium...done
# Processing Enterococcus casseliflavus...done
# Processing Enterobacter cloacae...done
# Processing Enterococcus faecalis...done
# Processing Enterococcus faecium...done
# Processing Enterococcus hirae...done
# Processing Enterobacter lignolyticus...done
# Processing Enterococcus mundtii...done
# Processing Enterobacter sp....done
# Processing Enterococcus sp....done
# Processing Erwinia amylovora...done
# Processing Erwinia billingiae...done
# Processing Erwinia pyrifoliae...done
# Processing Erwinia sp....done
# Processing Erwinia tasmaniensis...done
# Processing Erysipelothrix rhusiopathiae...done
# Processing Escherichia albertii...done
# Processing Escherichia coli...done
# Processing Escherichia fergusonii...done
# Processing Ethanoligenens harbinense...done
# Processing Eubacterium acidaminophilum...done
# Processing Eubacterium eligens...done
# Processing Eubacterium limosum...done
# Processing Eubacterium rectale...done
# Processing Eubacterium siraeum...done
# Processing Exiguobacterium antarcticum...done
# Processing Exiguobacterium sibiricum...done
# Processing Exiguobacterium sp....done
# Processing Faecalitalea cylindroides...done
# Processing Faecalibacterium prausnitzii...done
# Processing Ferrimonas balearica...done
# Processing Ferroglobus placidus...done
# Processing Fibrella aestuarina...done
# Processing Filifactor alocis...done
# Processing Finegoldia magna...done
# Processing Flavobacteriaceae bacterium...done
# Processing Flavobacterium branchiophilum...done
# Processing Flavobacterium columnare...done
# Processing Flavobacterium indicum...done
# Processing Flavobacterium johnsoniae...done
# Processing Flavobacterium psychrophilum...done
# Processing Flexibacter litoralis...done
# Processing Fluviicola taffensis...done
# Processing Formosa agariphila...done
# Processing Frankia alni...done
# Processing Francisella cf....done
# Processing Francisella guangzhouensis...done
# Processing Francisella noatunensis...done
# Processing Francisella philomiragia...done
# Processing Frankia sp....done
# Processing Francisella sp....done
# Processing Frankia symbiont...done
# Processing Francisella tularensis...done
# Processing Frateuria aurantia...done
# Processing Frischella perrara...done
# Processing Gallibacterium anatis...done
# Processing gamma proteobacterium...done
# Processing Gardnerella vaginalis...done
# Processing Geitlerinema sp....done
# Processing Geobacillus kaustophilus...done
# Processing Geobacillus sp....done
# Processing Geobacillus thermoglucosidasius...done
# Processing Geobacillus thermoleovorans...done
# Processing Geobacillus thermodenitrificans...done
# Processing Geodermatophilus obscurus...done
# Processing Geoglobus acetivorans...done
# Processing Gilliamella apicola...done
# Processing Glaciecola nitratireducens...done
# Processing Glaciecola psychrophila...done
# Processing Glaciecola sp....done
# Processing Gloeobacter kilaueensis...done
# Processing Gloeocapsa sp....done
# Processing Gordonia bronchialis...done
# Processing Gordonibacter pamelaeae...done
# Processing Gordonia polyisoprenivorans...done
# Processing Gordonia sp....done
# Processing Gramella forsetii...done
# Processing Gynuella sunshinyii...done
# Processing Haemophilus ducreyi...done
# Processing Haemophilus influenzae...done
# Processing Haemophilus parasuis...done
# Processing Haemophilus parainfluenzae...done
# Processing Hafnia alvei...done
# Processing Hahella chejuensis...done
# Processing Haloarcula marismortui...done
# Processing Halanaerobium hydrogeniformans...done
# Processing Halalkalicoccus jeotgali...done
# Processing Halanaerobium praevalens...done
# Processing Haliscomenobacter hydrossis...done
# Processing Halomonas campaniensis...done
# Processing Halomonas elongata...done
# Processing Halobacterium sp....done
# Processing Halorhodospira halochloris...done
# Processing Halobacillus halophilus...done
# Processing Halobacteroides halobius...done
# Processing Halorhodospira halophila...done
# Processing Haloarcula hispanica...done
# Processing Halorubrum lacusprofundi...done
# Processing Halostagnicola larsenii...done
# Processing Haloferax mediterranei...done
# Processing Halomicrobium mukohataei...done
# Processing Halothiobacillus neapolitanus...done
# Processing Halothermothrix orenii...done
# Processing Halovivax ruber...done
# Processing Haloarcula sp....done
# Processing Halomonas sp....done
# Processing Halothece sp....done
# Processing Halorhabdus tiamatea...done
# Processing Haloterrigena turkmenica...done
# Processing Halorhabdus utahensis...done
# Processing Haloferax volcanii...done
# Processing Haloquadratum walsbyi...done
# Processing Halopiger xanaduensis...done
# Processing Heliobacterium modesticaldum...done
# Processing Hydrogenobaculum sp....done
# Processing Hydrogenobacter thermophilus...done
# Processing Hymenobacter sp....done
# Processing Hymenobacter swuensis...done
# Processing Hyperthermus butylicus...done
# Processing Idiomarina loihiensis...done
# Processing Ignisphaera aggregans...done
# Processing Ignicoccus hospitalis...done
# Processing Ilumatobacter coccineus...done
# Processing Intrasporangium calvum...done
# Processing Isoptericola variabilis...done
# Processing Jeotgalicoccus sp....done
# Processing Jeotgalibacillus sp....done
# Processing Jonesia denitrificans...done
# Processing Kangiella koreensis...done
# Processing Kineococcus radiotolerans...done
# Processing Kitasatospora setae...done
# Processing Klebsiella michiganensis...done
# Processing Klebsiella oxytoca...done
# Processing Klebsiella pneumoniae...done
# Processing Klebsiella variicola...done
# Processing Kocuria rhizophila...done
# Processing Kosakonia sacchari...done
# Processing Kribbella flavida...done
# Processing Kutzneria albida...done
# Processing Kyrpidia tusciae...done
# Processing Kytococcus sedentarius...done
# Processing Lachnoclostridium phytofermentans...done
# Processing Lacinutrix sp....done
# Processing Lactobacillus acidophilus...done
# Processing Lactobacillus amylovorus...done
# Processing Lactobacillus brevis...done
# Processing Lactobacillus buchneri...done
# Processing Lactobacillus casei...done
# Processing Lactobacillus crispatus...done
# Processing Lactobacillus delbrueckii...done
# Processing Lactobacillus fermentum...done
# Processing Lactococcus garvieae...done
# Processing Lactobacillus gasseri...done
# Processing Lactobacillus helveticus...done
# Processing Lactobacillus hokkaidonensis...done
# Processing Lactobacillus johnsonii...done
# Processing Lactobacillus kefiranofaciens...done
# Processing Lactococcus lactis...done
# Processing Lactobacillus mucosae...done
# Processing Lactobacillus paracasei...done
# Processing Lactobacillus plantarum...done
# Processing Lactobacillus reuteri...done
# Processing Lactobacillus rhamnosus...done
# Processing Lactobacillus ruminis...done
# Processing Lactobacillus sakei...done
# Processing Lactobacillus salivarius...done
# Processing Lactobacillus sanfranciscensis...done
# Processing Lactobacillus sp....done
# Processing Leadbetterella byssophila...done
# Processing Legionella fallonii...done
# Processing Legionella hackeliae...done
# Processing Legionella longbeachae...done
# Processing Legionella oakridgensis...done
# Processing Legionella pneumophila...done
# Processing Leifsonia xyli...done
# Processing Leptospira biflexa...done
# Processing Leptospira interrogans...done
# Processing Leptolyngbya sp....done
# Processing Leuconostoc carnosum...done
# Processing Leuconostoc citreum...done
# Processing Leuconostoc gelidum...done
# Processing Leuconostoc kimchii...done
# Processing Leuconostoc mesenteroides...done
# Processing Leuconostoc sp....done
# Processing Listeria ivanovii...done
# Processing Listeria monocytogenes...done
# Processing Listeria seeligeri...done
# Processing Listeria welshimeri...done
# Processing Lysinibacillus fusiformis...done
# Processing Lysinibacillus sphaericus...done
# Processing Lysinibacillus varians...done
# Processing Macrococcus caseolyticus...done
# Processing Mageeibacillus indolicus...done
# Processing Mahella australiensis...done
# Processing Mannheimia haemolytica...done
# Processing Mannheimia succiniciproducens...done
# Processing Mannheimia varigena...done
# Processing Marinobacter adhaerens...done
# Processing Marinobacter hydrocarbonoclasticus...done
# Processing Marinomonas mediterranea...done
# Processing Marinomonas posidonica...done
# Processing Marichromatium purpuratum...done
# Processing Marinobacter salarius...done
# Processing Marinobacter similis...done
# Processing Marinobacter sp....done
# Processing Maribacter sp....done
# Processing Marinomonas sp....done
# Processing Marivirga tractuosa...done
# Processing Methanoculleus marisnigri...done
# Processing Megasphaera elsdenii...done
# Processing Megamonas hypermegale...done
# Processing Melissococcus plutonius...done
# Processing Methanosarcina acetivorans...done
# Processing Methanococcus maripaludis...done
# Processing Metallosphaera cuprina...done
# Processing Metallosphaera sedula...done
# Processing Methanococcus aeolicus...done
# Processing Methylomicrobium alcaliphilum...done
# Processing Methanocella arvoryzae...done
# Processing Methanosarcina barkeri...done
# Processing Methanoculleus bourgensis...done
# Processing Methanococcoides burtonii...done
# Processing Methylococcus capsulatus...done
# Processing Methanosaeta concilii...done
# Processing Methanohalobium evestigatum...done
# Processing Methanocaldococcus fervens...done
# Processing Methanothermus fervidus...done
# Processing Methanobacterium formicicum...done
# Processing Methanoregula formicica...done
# Processing Methylophaga frappieri...done
# Processing Methanosaeta harundinacea...done
# Processing Methanomethylovorans hollandica...done
# Processing Methanosarcina horonobensis...done
# Processing Methanospirillum hungatei...done
# Processing Methanotorris igneus...done
# Processing Methanocaldococcus infernus...done
# Processing Methanocaldococcus jannaschii...done
# Processing Methanopyrus kandleri...done
# Processing Methanocorpusculum labreanum...done
# Processing Methanobacterium lacus...done
# Processing Methanosarcina lacustris...done
# Processing Methanohalophilus mahii...done
# Processing Methanothermobacter marburgensis...done
# Processing Methanosarcina mazei...done
# Processing Methylomonas methanica...done
# Processing Methanococcoides methylutens...done
# Processing Methylophaga nitratireducenticrescens...done
# Processing Methanothermococcus okinawensis...done
# Processing Methanobacterium paludis...done
# Processing Methanocella paludicola...done
# Processing Methanosphaerula palustris...done
# Processing Methanolacinia petrolearia...done
# Processing Methanolobus psychrophilus...done
# Processing Methanobrevibacter ruminantium...done
# Processing Methanosarcina siciliae...done
# Processing Methanobrevibacter sp....done
# Processing Methanothermobacter sp....done
# Processing Methanocaldococcus sp....done
# Processing Methanosarcina sp....done
# Processing Methanobacterium sp....done
# Processing Methanosphaera stadtmanae...done
# Processing Methanolinea tarda...done
# Processing Methanothermobacter thermautotrophicus...done
# Processing Methanosaeta thermophila...done
# Processing Methanosarcina thermophila...done
# Processing Methanosarcina vacuolata...done
# Processing Methanococcus vannielii...done
# Processing Methanococcus voltae...done
# Processing Methanocaldococcus vulcanius...done
# Processing Methanosalsum zhilinae...done
# Processing Microcystis aeruginosa...done
# Processing Micromonospora aurantiaca...done
# Processing Micrococcus luteus...done
# Processing Microlunatus phosphovorus...done
# Processing Micromonospora sp....done
# Processing Microcoleus sp....done
# Processing Microbacterium testaceum...done
# Processing Mobiluncus curtisii...done
# Processing Modestobacter marinus...done
# Processing Moorella thermoacetica...done
# Processing Moraxella catarrhalis...done
# Processing Morganella morganii...done
# Processing Moritella viscosa...done
# Processing Mucinivorans hirudinis...done
# Processing Muricauda lutaonensis...done
# Processing Muricauda ruestringensis...done
# Processing Mycobacterium abscessus...done
# Processing Mycobacterium africanum...done
# Processing Mycobacterium avium...done
# Processing Mycobacterium bovis...done
# Processing Mycobacterium canettii...done
# Processing Mycobacterium chelonae...done
# Processing Mycobacterium chubuense...done
# Processing Mycobacterium gilvum...done
# Processing Mycobacterium indicus...done
# Processing Mycobacterium intracellulare...done
# Processing Mycobacterium kansasii...done
# Processing Mycobacterium leprae...done
# Processing Mycobacterium liflandii...done
# Processing Mycobacterium marinum...done
# Processing Mycobacterium neoaurum...done
# Processing Mycobacterium rhodesiae...done
# Processing Mycobacterium smegmatis...done
# Processing Mycobacterium sp....done
# Processing Mycobacterium tuberculosis...done
# Processing Mycobacterium ulcerans...done
# Processing Mycobacterium vanbaalenii...done
# Processing Mycobacterium yongonense...done
# Processing Myroides profundi...done
# Processing Myroides sp....done
# Processing Nakamurella multipartita...done
# Processing Natronobacterium gregoryi...done
# Processing Natrialba magadii...done
# Processing Natronomonas moolapensis...done
# Processing Natronococcus occultus...done
# Processing Natrinema pellirubrum...done
# Processing Natrinema sp....done
# Processing Niabella soli...done
# Processing Niastella koreensis...done
# Processing Nitrosococcus halophilus...done
# Processing Nitrosococcus oceani...done
# Processing Nitrosococcus watsonii...done
# Processing Nocardiopsis alba...done
# Processing Nocardia brasiliensis...done
# Processing Nocardia cyriacigeorgica...done
# Processing Nocardiopsis dassonvillei...done
# Processing Nocardia nova...done
# Processing Nocardioides sp....done
# Processing Nodularia spumigena...done
# Processing Nonlabens dokdonensis...done
# Processing Nonlabens marinus...done
# Processing Nostoc punctiforme...done
# Processing Nostoc sp....done
# Processing Oceanimonas sp....done
# Processing Odoribacter splanchnicus...done
# Processing Oenococcus kitaharae...done
# Processing Oenococcus oeni...done
# Processing Oleispira antarctica...done
# Processing Olsenella uli...done
# Processing Ornithobacterium rhinotracheale...done
# Processing Oscillatoria acuminata...done
# Processing Oscillatoria nigro-viridis...done
# Processing Oscillibacter valericigenes...done
# Processing Owenweeksia hongkongensis...done
# Processing Paenibacillus beijingensis...done
# Processing Paenibacillus borealis...done
# Processing Paenibacillus durus...done
# Processing Paenibacillus graminis...done
# Processing Paenibacillus larvae...done
# Processing Paenibacillus mucilaginosus...done
# Processing Paenibacillus odorifer...done
# Processing Paenibacillus polymyxa...done
# Processing Paenibacillus sabinae...done
# Processing Paenibacillus sp....done
# Processing Paenibacillus stellifer...done
# Processing Paenibacillus terrae...done
# Processing Palaeococcus pacificus...done
# Processing Paludibacter propionicigenes...done
# Processing Pantoea ananatis...done
# Processing Pantoea rwandensis...done
# Processing Pantoea sp....done
# Processing Pantoea vagans...done
# Processing Parabacteroides distasonis...done
# Processing Parvimonas micra...done
# Processing Pasteurella multocida...done
# Processing Pectobacterium atrosepticum...done
# Processing Pectobacterium carotovorum...done
# Processing Pectobacterium sp....done
# Processing Pectobacterium wasabiae...done
# Processing Pediococcus claussenii...done
# Processing Pediococcus pentosaceus...done
# Processing Pedobacter heparinus...done
# Processing Pedobacter saltans...done
# Processing Pelosinus fermentans...done
# Processing Pelosinus sp....done
# Processing Pelotomaculum thermopropionicum...done
# Processing Peptoclostridium difficile...done
# Processing Peptoniphilus sp....done
# Processing Photorhabdus asymbiotica...done
# Processing Photobacterium gaetbulicola...done
# Processing Picrophilus torridus...done
# Processing Pimelobacter simplex...done
# Processing Planococcus sp....done
# Processing Plautia stali...done
# Processing Pleurocapsa sp....done
# Processing Pluralibacter gergoviae...done
# Processing Polaribacter sp....done
# Processing Pontibacter korlensis...done
# Processing Porphyromonas asaccharolytica...done
# Processing Porphyromonadaceae bacterium...done
# Processing Porphyromonas gingivalis...done
# Processing Prevotella dentalis...done
# Processing Prevotella denticola...done
# Processing Prevotella intermedia...done
# Processing Prevotella melaninogenica...done
# Processing Prevotella ruminicola...done
# Processing Prevotella sp....done
# Processing Prochlorococcus marinus...done
# Processing Prochlorococcus sp....done
# Processing Propionibacterium acidipropionici...done
# Processing Propionibacterium acnes...done
# Processing Propionibacterium avidum...done
# Processing Propionibacterium freudenreichii...done
# Processing Propionibacterium propionicum...done
# Processing Proteus mirabilis...done
# Processing Providencia stuartii...done
# Processing Pseudomonas aeruginosa...done
# Processing Pseudomonas alkylphenolia...done
# Processing Pseudoalteromonas atlantica...done
# Processing Pseudomonas balearica...done
# Processing Pseudomonas brassicacearum...done
# Processing Pseudomonas chlororaphis...done
# Processing Pseudomonas cichorii...done
# Processing Pseudomonas cremoricolorata...done
# Processing Pseudomonas denitrificans...done
# Processing Pseudonocardia dioxanivorans...done
# Processing Pseudomonas entomophila...done
# Processing Pseudomonas fluorescens...done
# Processing Pseudomonas fulva...done
# Processing Pseudoalteromonas haloplanktis...done
# Processing Pseudomonas knackmussii...done
# Processing Pseudomonas mandelii...done
# Processing Pseudomonas mendocina...done
# Processing Pseudomonas monteilii...done
# Processing Pseudomonas mosselii...done
# Processing Pseudomonas parafulva...done
# Processing Pseudomonas plecoglossicida...done
# Processing Pseudomonas poae...done
# Processing Pseudomonas protegens...done
# Processing Pseudomonas pseudoalcaligenes...done
# Processing Pseudomonas putida...done
# Processing Pseudomonas resinovorans...done
# Processing Pseudomonas rhizosphaerae...done
# Processing Pseudomonas savastanoi...done
# Processing Pseudomonas simiae...done
# Processing Pseudomonas sp....done
# Processing Pseudoalteromonas sp....done
# Processing Pseudanabaena sp....done
# Processing Pseudoxanthomonas spadix...done
# Processing Pseudomonas stutzeri...done
# Processing Pseudoxanthomonas suwonensis...done
# Processing Pseudomonas syringae...done
# Processing Psychrobacter arcticus...done
# Processing Psychrobacter cryohalolentis...done
# Processing Psychromonas ingrahamii...done
# Processing Psychromonas sp....done
# Processing Psychrobacter sp....done
# Processing Psychroflexus torquis...done
# Processing Pyrobaculum aerophilum...done
# Processing Pyrococcus furiosus...done
# Processing Pyrococcus horikoshii...done
# Processing Pyrobaculum sp....done
# Processing Pyrobaculum arsenaticum...done
# Processing Pyrobaculum calidifontis...done
# Processing Pyrococcus sp....done
# Processing Pyrobaculum oguniense...done
# Processing Pyrococcus yayanosii...done
# Processing Rahnella aquatilis...done
# Processing Rahnella sp....done
# Processing Raoultella ornithinolytica...done
# Processing Rathayibacter toxicus...done
# Processing Renibacterium salmoninarum...done
# Processing Rhodanobacter denitrificans...done
# Processing Rhodococcus equi...done
# Processing Rhodococcus erythropolis...done
# Processing Rhodococcus jostii...done
# Processing Rhodoluna lacicola...done
# Processing Rhodococcus opacus...done
# Processing Rhodococcus pyridinivorans...done
# Processing Rhodococcus sp....done
# Processing Riemerella anatipestifer...done
# Processing Rivularia sp....done
# Processing Robiginitalea biformata...done
# Processing Roseburia hominis...done
# Processing Roseburia intestinalis...done
# Processing Rothia dentocariosa...done
# Processing Rothia mucilaginosa...done
# Processing Rubrobacter radiotolerans...done
# Processing Rubrobacter xylanophilus...done
# Processing Ruminococcus albus...done
# Processing Ruminococcus bicirculans...done
# Processing Ruminococcus bromii...done
# Processing Ruminococcus champanellensis...done
# Processing Ruminococcus obeum...done
# Processing Ruminococcus sp....done
# Processing Ruminiclostridium thermocellum...done
# Processing Ruminococcus torques...done
# Processing Runella slithyformis...done
# Processing Saccharophagus degradans...done
# Processing Saccharopolyspora erythraea...done
# Processing Saccharothrix espanaensis...done
# Processing Saccharomonospora viridis...done
# Processing Salinispora arenicola...done
# Processing Salinispira pacifica...done
# Processing Salinarchaeum sp....done
# Processing Salinispora tropica...done
# Processing Salmonella bongori...done
# Processing Salmonella enterica...done
# Processing Sanguibacter keddieii...done
# Processing Saprospira grandis...done
# Processing secondary endosymbiont...done
# Processing Segniliparus rotundus...done
# Processing Selenomonas ruminantium...done
# Processing Selenomonas sputigena...done
# Processing Serratia liquefaciens...done
# Processing Serratia marcescens...done
# Processing Serratia multitudinisentens...done
# Processing Serratia plymuthica...done
# Processing Serratia proteamaculans...done
# Processing Serratia sp....done
# Processing Serratia symbiotica...done
# Processing Shewanella baltica...done
# Processing Shewanella piezotolerans...done
# Processing Shewanella putrefaciens...done
# Processing Shewanella sediminis...done
# Processing Shewanella violacea...done
# Processing Shigella boydii...done
# Processing Shigella dysenteriae...done
# Processing Shigella flexneri...done
# Processing Shigella sonnei...done
# Processing Shimwellia blattae...done
# Processing Siansivirga zeaxanthinifaciens...done
# Processing Simiduia agarivorans...done
# Processing Slackia heliotrinireducens...done
# Processing Sodalis glossinidius...done
# Processing Sodalis praecaptivus...done
# Processing Solitalea canadensis...done
# Processing Solibacillus silvestris...done
# Processing Sphaerochaeta coccoides...done
# Processing Sphaerochaeta globosa...done
# Processing Sphaerochaeta pleomorpha...done
# Processing Sphingobacterium sp....done
# Processing Spirochaeta africana...done
# Processing Spirosoma linguale...done
# Processing Spirosoma radiotolerans...done
# Processing Spiribacter salinus...done
# Processing Spirochaeta smaragdinae...done
# Processing Spiribacter sp....done
# Processing Spirochaeta thermophila...done
# Processing Stackebrandtia nassauensis...done
# Processing Stanieria cyanosphaera...done
# Processing Staphylococcus aureus...done
# Processing Staphylococcus carnosus...done
# Processing Staphylococcus epidermidis...done
# Processing Staphylococcus haemolyticus...done
# Processing Staphylothermus hellenicus...done
# Processing Staphylococcus hyicus...done
# Processing Staphylococcus lugdunensis...done
# Processing Staphylothermus marinus...done
# Processing Staphylococcus pasteuri...done
# Processing Staphylococcus pseudintermedius...done
# Processing Staphylococcus saprophyticus...done
# Processing Staphylococcus warneri...done
# Processing Staphylococcus xylosus...done
# Processing Stenotrophomonas maltophilia...done
# Processing Stenotrophomonas rhizophila...done
# Processing Streptococcus agalactiae...done
# Processing Streptomyces albus...done
# Processing Streptomyces albulus...done
# Processing Streptococcus anginosus...done
# Processing Streptomyces avermitilis...done
# Processing Streptomyces bingchenggensis...done
# Processing Streptomyces cattleya...done
# Processing Streptomyces collinus...done
# Processing Streptococcus constellatus...done
# Processing Streptomyces cyaneogriseus...done
# Processing Streptomyces davawensis...done
# Processing Streptococcus dysgalactiae...done
# Processing Streptococcus equi...done
# Processing Streptomyces fulvissimus...done
# Processing Streptococcus gallolyticus...done
# Processing Streptomyces glaucescens...done
# Processing Streptococcus gordonii...done
# Processing Streptomyces griseus...done
# Processing Streptomyces hygroscopicus...done
# Processing Streptococcus infantarius...done
# Processing Streptococcus iniae...done
# Processing Streptococcus intermedius...done
# Processing Streptomyces lividans...done
# Processing Streptococcus lutetiensis...done
# Processing Streptomyces lydicus...done
# Processing Streptococcus macedonicus...done
# Processing Streptococcus mitis...done
# Processing Streptococcus mutans...done
# Processing Streptomyces nodosus...done
# Processing Streptococcus oligofermentans...done
# Processing Streptococcus oralis...done
# Processing Streptococcus parasanguinis...done
# Processing Streptococcus parauberis...done
# Processing Streptococcus pasteurianus...done
# Processing Streptococcus pneumoniae...done
# Processing Streptomyces pratensis...done
# Processing Streptococcus pseudopneumoniae...done
# Processing Streptococcus pyogenes...done
# Processing Streptomyces rapamycinicus...done
# Processing Streptosporangium roseum...done
# Processing Streptococcus salivarius...done
# Processing Streptococcus sanguinis...done
# Processing Streptomyces scabiei...done
# Processing Streptomyces sp....done
# Processing Streptococcus sp....done
# Processing Streptococcus suis...done
# Processing Streptococcus thermophilus...done
# Processing Streptococcus uberis...done
# Processing Streptomyces venezuelae...done
# Processing Streptomyces vietnamensis...done
# Processing Streptomyces violaceusniger...done
# Processing Sulfolobus solfataricus...done
# Processing Sulfolobus acidocaldarius...done
# Processing Sulfobacillus acidophilus...done
# Processing Sulfolobus islandicus...done
# Processing Sulfurihydrogenibium sp....done
# Processing Sulfolobus tokodaii...done
# Processing Symbiobacterium thermophilum...done
# Processing Synechococcus elongatus...done
# Processing Synechococcus sp....done
# Processing Synechocystis sp....done
# Processing synthetic Escherichia...done
# Processing Syntrophobotulus glycolicus...done
# Processing Syntrophothermus lipocalidus...done
# Processing Syntrophomonas wolfei...done
# Processing Tannerella forsythia...done
# Processing Tatlockia micdadei...done
# Processing Tepidanaerobacter acetatoxydans...done
# Processing Teredinibacter turnerae...done
# Processing Terribacillus aidingensis...done
# Processing Tetragenococcus halophilus...done
# Processing Thalassolituus oleivorans...done
# Processing Thermoplasma acidophilum...done
# Processing Thermosphaera aggregans...done
# Processing Thermocrinis albus...done
# Processing Thermoplasmatales archaeon...done
# Processing Thermococcus barophilus...done
# Processing Thermobispora bispora...done
# Processing Thermoanaerobacter brockii...done
# Processing Thermobacillus composti...done
# Processing Thermococcus eurythermalis...done
# Processing Thermobifida fusca...done
# Processing Thermoanaerobacter italicus...done
# Processing Thermoanaerobacter kivui...done
# Processing Thermococcus kodakarensis...done
# Processing Thermococcus litoralis...done
# Processing Thermaerobacter marianensis...done
# Processing Thermoanaerobacter mathranii...done
# Processing Thermodesulfobium narugense...done
# Processing Thermococcus nautili...done
# Processing Thermosediminibacter oceani...done
# Processing Thermococcus onnurineus...done
# Processing Thermofilum pendens...done
# Processing Thermacetogenium phaeum...done
# Processing Thermincola potens...done
# Processing Thermoanaerobacter pseudethanolicus...done
# Processing Thermocrinis ruber...done
# Processing Thermoanaerobacterium saccharolyticum...done
# Processing Thermococcus sibiricus...done
# Processing Thermococcus sp....done
# Processing Thermosynechococcus sp....done
# Processing Thermoanaerobacter sp....done
# Processing Thermoproteus tenax...done
# Processing Thermoanaerobacterium thermosaccharolyticum...done
# Processing Thermoproteus uzoniensis...done
# Processing Thermoplasma volcanium...done
# Processing Thermoanaerobacter wiegelii...done
# Processing Thermoanaerobacterium xylanolyticum...done
# Processing Thioalkalimicrobium aerophilum...done
# Processing Thiolapillus brandeum...done
# Processing Thiomicrospira crunogena...done
# Processing Thioalkalimicrobium cyclicum...done
# Processing Thioploca ingrica...done
# Processing Thioflavicoccus mobilis...done
# Processing Thioalkalivibrio nitratireducens...done
# Processing Thioalkalivibrio sp....done
# Processing Thioalkalivibrio sulfidiphilus...done
# Processing Thioalkalivibrio thiocyanoxidans...done
# Processing Thiocystis violascens...done
# Processing Tolumonas auensis...done
# Processing Treponema azotonutricium...done
# Processing Treponema brennaborense...done
# Processing Treponema caldaria...done
# Processing Treponema denticola...done
# Processing Treponema pallidum...done
# Processing Treponema paraluiscuniculi...done
# Processing Treponema pedis...done
# Processing Treponema primitia...done
# Processing Treponema putidum...done
# Processing Treponema sp....done
# Processing Treponema succinifaciens...done
# Processing Trichodesmium erythraeum...done
# Processing Tropheryma whipplei...done
# Processing Trueperella pyogenes...done
# Processing Tsukamurella paurometabola...done
# Processing Turneriella parva...done
# Processing Veillonella parvula...done
# Processing Verrucosispora maris...done
# Processing Vibrio alginolyticus...done
# Processing Vibrio anguillarum...done
# Processing Vibrio campbellii...done
# Processing Vibrio cholerae...done
# Processing Vibrio coralliilyticus...done
# Processing Vibrio furnissii...done
# Processing Vibrio nigripulchritudo...done
# Processing Vibrio parahaemolyticus...done
# Processing Vibrio sp....done
# Processing Vibrio tasmaniensis...done
# Processing Vibrio tubiashii...done
# Processing Vibrio vulnificus...done
# Processing Virgibacillus sp....done
# Processing Vulcanisaeta distributa...done
# Processing Vulcanisaeta moutnovskia...done
# Processing Weeksella virosa...done
# Processing Weissella ceti...done
# Processing Weissella koreensis...done
# Processing Wigglesworthia glossinidia...done
# Processing Winogradskyella sp....done
# Processing Xanthomonas albilineans...done
# Processing Xanthomonas axonopodis...done
# Processing Xanthomonas campestris...done
# Processing Xanthomonas citri...done
# Processing Xanthomonas fuscans...done
# Processing Xanthomonas oryzae...done
# Processing Xanthomonas sacchari...done
# Processing Xenorhabdus bovienii...done
# Processing Xenorhabdus doucetiae...done
# Processing Xenorhabdus nematophila...done
# Processing Xenorhabdus poinarii...done
# Processing Xylanimonas cellulosilytica...done
# Processing Xylella fastidiosa...done
# Processing Yersinia aldovae...done
# Processing Yersinia enterocolitica...done
# Processing Yersinia frederiksenii...done
# Processing Yersinia intermedia...done
# Processing Yersinia kristensenii...done
# Processing Yersinia pestis...done
# Processing Yersinia pseudotuberculosis...done
# Processing Yersinia rohdei...done
# Processing Yersinia ruckeri...done
# Processing Yersinia similis...done
# Processing Zobellia galactanivorans...done
# Processing Zunongwangia profunda...done

# %% [markdown]
# ## Export to R
#
# R has superior visualization capabilities.
#
# ### Order columns
#
# To make it look pretty.

# %%
def position_str_to_int(position):
  if position == "20a": return 20.1
  if position == "20b": return 20.2
  digits = re.findall('\d+', position)
  if len(digits) == 0: return -1
  insert = 0
  if 'i' in position and len(digits) == 2: insert = float(digits[1]) / 1000
  if position[0] == 'V':
    if ':' in position: return int(digits[0]) + 45 - 10 + insert # V11~V17
    else: return int(digits[0]) + 45 + 7 + insert # V1~V5
  if int(digits[0]) >= 46: return int(digits[0]) + 50 + insert # just add an arbitrarily large number to skip v-arm
  return int(digits[0]) + insert

identities = identities[sorted(list(identities.columns), key=position_str_to_int)]

# %%
identities.to_csv(path_or_buf='identities.tsv', sep='\t', index_label=False)

# %%
identities.head()
# Out:
#            clade    domain isotype                              seqname               species                    species_long                  taxid isotype_best anticodon  score  isoscore  isoscore_ac intron        GC  insertions  deletions  restrict 1:72  1 1i1 2:71  2 2i1 3:70  3 3i1 3i2 3i3 3i4 3i5 3i6 4:69  4 4i1 4i2 4i3 5:68  5 6:67  6 6i1 6i2 7:66  7 7i1 7i2  8 8i1  9 9i1 10:25 10 10i1 10i2 11:24 11 12:23 12 12i1 13:22 13 13i1 13i2 13i3 13i4 13i5 14 14i1 14i2 14i3 14i4 14i5 14i6 14i7 14i8 14i9 14i10 14i11 14i12 14i13 14i14 14i15 15 15i1 15i2 15i3 15i4 15i5 15i6 15i7 15i8 15i9 16 16i1 16i2 16i3 16i4 16i5 16i6 16i7 16i8 16i9 16i10 16i11 16i12 16i13 16i14 16i15 16i16 16i17 16i18 16i19 16i20 16i21 16i22 16i23 16i24 16i25 16i26 16i27 16i28 16i29 16i30 16i31 16i32 16i33 16i34 16i35 16i36 16i37 16i38 16i39 16i40 16i41 16i42 16i43 16i44 16i45 16i46 16i47 16i48 16i49 16i50 17 17a 18 19 19i1 19i2 19i3 19i4 19i5 19i6 19i7 19i8 19i9 19i10 19i11 19i12 19i13 19i14 19i15 19i16 19i17 19i18 19i19 19i20 19i21 19i22 19i23 19i24 19i25 19i26 19i27 19i28 19i29 19i30 19i31 19i32 19i33 19i34 19i35 19i36 20 20i1 20a 20b 21 22 22i1 22i2 23 23i1 23i2 23i3 23i4 23i5 23i6 23i7 23i8 23i9 23i10 23i11 23i12 23i13 23i14 23i15 23i16 24 24i1 25 26 26i1 26i2 27:43 27 27i1 28:42 28 28i1 29:41 29 29i1 30:40 30 30i1 31:39 31 31i1 32 32i1 32i2 32i3 32i4 33 34 35 36 37 37i1 37i2 37i3 37i4 37i5 37i6 37i7 37i8 37i9 37i10 37i11 37i12 37i13 37i14 37i15 37i16 37i17 37i18 37i19 37i20 37i21 37i22 37i23 37i24 37i25 37i26 37i27 37i28 37i29 37i30 37i31 37i32 37i33 37i34 37i35 37i36 37i37 37i38 37i39 37i40 37i41 37i42 37i43 37i44 37i45 37i46 37i47 38 38i1 38i2 39 39i1 40 41 41i1 42 42i1 43 44 44i1 44i2 44i3 44i4 44i5 44i6 44i7 44i8 44i9 44i10 44i11 44i12 44i13 44i14 44i15 44i16 44i17 44i18 44i19 44i20 44i21 44i22 45 V11:V21 V12:V22 V13:V23 V14:V24 V15:V25 V16:V26 V17:V27 V1 V2 V3 V4 V5 V11 V12 V13 V14 V15 V16 V17 V21 V22 V23 V24 V25 V26 V27 46 47 47i1 47i2 47i3 47i4 47i5 47i6 48 49:65 49 50:64 50 50i1 51:63 51 51i1 52:62 52 52i1 53:61 53 53i1 53i2 53i3 53i4 53i5 53i6 53i7 53i8 53i9 53i10 53i11 53i12 53i13 53i14 53i15 53i16 53i17 53i18 53i19 53i20 53i21 53i22 53i23 53i24 53i25 53i26 53i27 53i28 53i29 53i30 53i31 53i32 53i33 53i34 53i35 53i36 53i37 53i38 53i39 53i40 54 54i1 55 56 57 57i1 58 59 59i1 59i2 59i3 60 60i1 60i2 60i3 60i4 60i5 60i6 60i7 60i8 60i9 60i10 60i11 60i12 60i13 60i14 60i15 60i16 60i17 60i18 60i19 60i20 60i21 60i22 60i23 60i24 60i25 60i26 60i27 60i28 60i29 60i30 60i31 60i32 60i33 60i34 60i35 60i36 60i37 60i38 60i39 60i40 60i41 60i42 60i43 60i44 60i45 60i46 60i47 60i48 60i49 60i50 60i51 60i52 60i53 60i54 60i55 60i56 60i57 60i58 60i59 60i60 60i61 60i62 60i63 60i64 60i65 60i66 60i67 60i68 61 62 62i1 62i2 63 63i1 64 64i1 64i2 65 65i1 66 66i1 67 67i1 67i2 67i3 67i4 68 68i1 68i2 68i3 69 69i1 70 70i1 71 71i1 72 72i1 72i2 73 74 75 76
# 0  Cyanobacteria  bacteria     Arg  acarMari_MBIC11017_chr.trna1-ArgTCT  Acaryochloris marina  Acaryochloris marina MBIC11017  Oscillatoriophycideae          Arg       TCT   80.5      96.2         96.2      0  0.535714           0          0     False  G:C  G   .  C:G  C   .  G:C  G   .   .   .   .   .   .  C:G  C   .   .   .  U:A  U  C:G  C   .   .  G:C  G   .   .  U   .  A   .   G:C  G    .    .   C:G  C   U:A  U    .   C:G  C    .    .    .    .    .  A    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .  G    .    .    .    .    .    .    .    .    .  C    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  -   -  G  G    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  A    .   U   -  A  G    .    .  A    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .  G    .  C  A    .    .   G:U  G    .   U:A  U    .   U:A  U    .   G:C  G    .   C:G  C    .  C    .    .    .    .  U  U  C  U  A    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  A    .    .  G    .  C  A    .  A    .  U  U    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .  G     -:-     -:-     -:-     -:-     -:-     -:-     -:-  -  -  -  -  -   -   -   -   -   -   -   -   -   -   -   -   -   -   -  G  U    .    .    .    .    .    .  C   G:C  G   C:G  C    .   A:U  A    .   G:C  G    .   G:C  G    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  U    .  U  C  G    .  A  G    .    .    .  U    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  C  C    .    .  U    .  G    .    .  C    .  C    .  G    .    .    .    .  A    .    .    .  G    .  C    .  G    .  C    .    .  G  -  -  -
# 1  Cyanobacteria  bacteria     Asp  acarMari_MBIC11017_chr.trna2-AspGTC  Acaryochloris marina  Acaryochloris marina MBIC11017  Oscillatoriophycideae          Pro       GTC   71.8      82.6         60.2      0  0.571429           0          0     False  G:C  G   .  G:C  G   .  G:C  G   .   .   .   .   .   .  G:C  G   .   .   .  G:C  G  U:U  U   .   .  G:C  G   .   .  U   .  A   .   G:C  G    .    .   C:G  C   U:A  U    .   C:G  C    .    .    .    .    .  A    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .  G    .    .    .    .    .    .    .    .    .  U    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  C   -  G  G    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  U    .   C   U  A  G    .    .  A    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .  G    .  C  A    .    .   G:A  G    .   U:A  U    .   C:G  C    .   G:C  G    .   C:G  C    .  C    .    .    .    .  U  G  U  C  G    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  A    .    .  G    .  C  G    .  A    .  A  A    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .  G     -:-     -:-     -:-     -:-     -:-     -:-     -:-  -  -  -  -  -   -   -   -   -   -   -   -   -   -   -   -   -   -   -  G  U    .    .    .    .    .    .  C   G:U  G   C:G  C    .   G:C  G    .   G:C  G    .   G:C  G    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  U    .  U  C  A    .  A  A    .    .    .  U    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  C  C    .    .  C    .  G    .    .  U    .  C    .  U    .    .    .    .  C    .    .    .  C    .  C    .  C    .  C    .    .  G  -  -  -
# 2  Cyanobacteria  bacteria     Cys  acarMari_MBIC11017_chr.trna3-CysGCA  Acaryochloris marina  Acaryochloris marina MBIC11017  Oscillatoriophycideae          Cys       GCA   65.6      73.1         73.1      0  0.500000           0          1     False  G:C  G   .  U:A  U   .  C:G  C   .   .   .   .   .   .  C:G  C   .   .   .  A:U  A  G:C  G   .   .  G:C  G   .   .  U   .  C   .   G:C  G    .    .   C:G  C   C:G  C    .   A:A  A    .    .    .    .    .  A    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .  G    .    .    .    .    .    .    .    .    .  G    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  -   -  G  G    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  U    .   C   G  A  A    .    .  G    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .  G    .  C  G    .    .   U:A  U    .   C:G  C    .   G:C  G    .   G:U  G    .   U:A  U    .  C    .    .    .    .  U  G  C  A  A    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  A    .    .  A    .  U  C    .  G    .  A  U    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .  -     -:-     -:-     -:-     -:-     -:-     -:-     -:-  -  -  -  -  -   -   -   -   -   -   -   -   -   -   -   -   -   -   -  A  U    .    .    .    .    .    .  C   G:C  G   U:A  U    .   G:C  G    .   G:C  G    .   G:C  G    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  U    .  U  C  A    .  A  C    .    .    .  U    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  C  C    .    .  C    .  A    .    .  C    .  C    .  C    .    .    .    .  U    .    .    .  G    .  G    .  A    .  C    .    .  U  C  C  A
# 3  Cyanobacteria  bacteria     Trp  acarMari_MBIC11017_chr.trna4-TrpCCA  Acaryochloris marina  Acaryochloris marina MBIC11017  Oscillatoriophycideae          Trp       CCA   55.1      59.9         59.9      0  0.428571           0          1     False  G:C  G   .  C:G  C   .  G:C  G   .   .   .   .   .   .  G:C  G   .   .   .  G:U  G  G:C  G   .   .  A:U  A   .   .  U   .  G   .   G:C  G    .    .   U:A  U   G:C  G    .   U:A  U    .    .    .    .    .  A    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .  A    .    .    .    .    .    .    .    .    .  U    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  -   -  G  G    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  C    .   -   -  A  A    .    .  C    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .  A    .  C  C    .    .   U:A  U    .   C:G  C    .   A:U  A    .   G:C  G    .   U:G  U    .  C    .    .    .    .  U  C  C  A  A    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  A    .    .  G    .  C  U    .  G    .  A  U    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .  -     -:-     -:-     -:-     -:-     -:-     -:-     -:-  -  -  -  -  -   -   -   -   -   -   -   -   -   -   -   -   -   -   -  G  U    .    .    .    .    .    .  U   C:G  C   U:A  U    .   G:U  G    .   G:C  G    .   G:C  G    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  U    .  U  C  A    .  A  A    .    .    .  U    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  C  C    .    .  U    .  A    .    .  G    .  U    .  C    .    .    .    .  U    .    .    .  C    .  C    .  G    .  C    .    .  G  -  -  -
# 4  Cyanobacteria  bacteria     Glu  acarMari_MBIC11017_chr.trna5-GluTTC  Acaryochloris marina  Acaryochloris marina MBIC11017  Oscillatoriophycideae          Gln       TTC   64.2      53.1         34.1      0  0.464286           0          0     False  A:U  A   .  G:C  G   .  U:A  U   .   .   .   .   .   .  G:C  G   .   .   .  G:C  G  U:A  U   .   .  G:C  G   .   .  U   .  A   .   C:G  C    .    .   G:C  G   C:G  C    .   A:A  A    .    .    .    .    .  A    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .  A    .    .    .    .    .    .    .    .    .  U    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  -   -  G  G    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  U    .   U   U  A  A    .    .  G    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .  C    .  G  A    .    .   C:G  C    .   U:A  U    .   U:A  U    .   G:C  G    .   A:C  A    .  U    .    .    .    .  U  U  U  C  A    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  A    .    .  C    .  C  A    .  A    .  G  U    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .  G     -:-     -:-     -:-     -:-     -:-     -:-     -:-  -  -  -  -  -   -   -   -   -   -   -   -   -   -   -   -   -   -   -  A  U    .    .    .    .    .    .  U   G:U  G   C:G  C    .   G:C  G    .   G:C  G    .   G:C  G    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  U    .  U  C  A    .  A  A    .    .    .  U    .    .    .    .    .    .    .    .    .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .     .  C  C    .    .  C    .  G    .    .  U    .  C    .  A    .    .    .    .  C    .    .    .  C    .  A    .  C    .  U    .    .  C  C  C  A
